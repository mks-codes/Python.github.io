# %% [markdown]
# <a href="https://colab.research.google.com/github/mks-codes/Python.github.io/blob/main/StaticsMethod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🧠 What is a @staticmethod in Python?
# A @staticmethod is a method inside a class that does not take self or cls as its first argument.
# It behaves like a normal function but is grouped inside a class for organizational purposes.
#
# 🤔 Why use @staticmethod?
# When you want a function to be logically related to a class, but it doesn’t need to access any instance (self) or class (cls) variables.
#
# For utility functions.

# %% [markdown]
# 🔧 Syntax:

# %%
class MyClass:
    @staticmethod
    def my_static_method():
        print("This is a static method.")

# %% [markdown]
# Call it like this:

# %%
MyClass.my_static_method()
# OR
obj = MyClass()
obj.my_static_method()
# Out:
# This is a static method.
# This is a static method.

# %%
class my:
  def add(mks):
    return f"{mks}"
my.add('magdum')
# Out:
# 'magdum'

# %% [markdown]
# 🔍 So, Why Use @staticmethod?
# Without @staticmethod	With @staticmethod
# Treated as a plain function	Treated as class utility function
# Breaks on instance call	Works on both class & instance
# No clear intention	Clearly says "I don't need self or cls"
